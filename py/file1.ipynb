# %%
abc = [1, 2, 3]
print(abc)

# %%
abc = [1, 2, "Labeeb"]
print(abc)
# Out:
# [1, 2, 'Labeeb']

# %%
suigha = set(["england", "india", "india", "gidsbfnd"])

# %%
print(suigha)
# Out:
# {'india', 'gidsbfnd', 'england'}
